# %% [markdown]
# ## MRSegmentator v1.1 VS v1.2
# TLDR: Better on NAKO data, same perfomance on other datasets
#
# In our [preprint](https://arxiv.org/pdf/2405.06463) (version 1.1) we evaluated MRSegmentator on external data. At the time of writing no suitable external dataset existed so we created our own. For this we annoated 900 scans from the NAKO dataset.
# Now, another dataset has been released, which we can evaluate our model on: the TotalSegmentator MRI dataset ([zenodo](https://zenodo.org/records/11367005)).
#
# Consequently, we moved the NAKO data to the training partition and retrained MRSegmentator (version 1.2). Below you can find the updated evaluation using our test datasets:
#
# |Dataset|MRSegmentator v1.1|MRSegmentator v1.2|
# | :-------- | :-------: | :-------: |
# | NAKO GRE MRI | 0.88  | 0.91* |
# | NAKO T2-HASTE MRI | 0.85 | 0.89* |
# | AMOS MRI | 0.79 | 0.79 |
# | AMOS CT | 0.84 | 0.84 |
# | TotalSegmentator MRI |0.74 | 0.74 |
#
# *We evaluated the NAKO scans in a 5-fold cross-validation setting.
#
# Segmentation performance has been largely improved for the NAKO data, while performance on the other datasets remained the same. This suggests that the performance increase is in some-parts caused by the bias that comes from changing the NAKO dataset from an "external" to an "internal" test/validation dataset.
# Nevertheless, given that version 1.2 is as good as version 1.1 on the other datasets and better for NAKO data, we believe it to be the better version overall.

# %%
import pandas as pd

pd.options.display.float_format = "{:,.2f}".format

data = pd.read_csv("csvs/classwise_results.csv", index_col=0)
averaged_data = pd.DataFrame(columns=["MRSegmentator v1.1", "MRSegmentator v1.2"])
averaged_data.loc["NAKO GRE MRI"] = data["NAKO GRE v1.1"].mean(), data["NAKO GRE v1.2"].mean()
averaged_data.loc["NAKO T2-HASTE MRI"] = data["NAKO T2 v1.1"].mean(), data["NAKO T2 v1.2"].mean()
averaged_data.loc["AMOS MRI"] = data["AMOS MRI v1.1"].mean(), data["AMOS MRI v1.2"].mean()
averaged_data.loc["AMOS CT"] = data["AMOS CT v1.1"].mean(), data["AMOS CT v1.2"].mean()
averaged_data.loc["TotalSegmentator MRI"] = (
    data["TotSeg MRI v1.1"].mean(),
    data["TotSeg MRI v1.2"].mean(),
)
averaged_data
# Out:
#                       MRSegmentator v1.1  MRSegmentator v1.2
# NAKO GRE MRI                        0.88                0.91
# NAKO T2-HASTE MRI                   0.85                0.89
# AMOS MRI                            0.79                0.79
# AMOS CT                             0.84                0.84
# TotalSegmentator MRI                0.74                0.74

# %%
data
# Out:
#                               NAKO GRE v1.1  NAKO GRE v1.2  NAKO T2 v1.1
# spleen                                 0.91           0.93          0.91  \
# right_kidney                           0.95           0.97          0.95
# left_kidney                            0.93           0.95          0.95
# gallbladder                            0.74           0.74          0.75
# liver                                  0.96           0.97          0.95
# stomach                                0.91           0.93          0.84
# pancreas                               0.82           0.85          0.80
# right_adrenal_gland                    0.69           0.74          0.72
# left_adrenal_gland                     0.69           0.74          0.69
# left_lung                              0.96           0.97          0.96
# right_lung                             0.96           0.97          0.96
# heart                                  0.94           0.95          0.92
# aorta                                  0.93           0.95          0.94
# inferior_vena_cava                     0.86           0.89          0.89
# portal_vein_and_splenic_vein           0.64           0.77          0.78
# left_iliac_artery                      0.81           0.84           NaN
# right_iliac_artery                     0.77           0.80           NaN
# left_iliac_vena                        0.88           0.90           NaN
# right_iliac_vena                       0.86           0.89           NaN
# esophagus                              0.81           0.86          0.79
# small_bowel                            0.76           0.81          0.57
# duodenum                               0.77           0.81          0.43
# colon                                  0.85           0.88          0.82
# urinary_bladder                        0.95           0.96           NaN
# spine                                  0.90           0.92          0.93
# sacrum                                 0.93           0.94           NaN
# left_hip                               0.93           0.94           NaN
# right_hip                              0.93           0.94           NaN
# left_femur                             0.93           0.94           NaN
# right_femur                            0.92           0.93           NaN
# left_autochthonous_muscle              0.94           0.96          0.95
# right_autochthonous_muscle             0.95           0.96          0.95
# left_iliopsoas_muscle                  0.93           0.96          0.95
# right_iliopsoas_muscle                 0.94           0.96          0.96
# left_gluteus_maximus                   0.93           0.94           NaN
# right_gluteus_maximus                  0.95           0.96           NaN
# left_gluteus_medius                    0.94           0.95           NaN
# right_gluteus_medius                   0.94           0.95           NaN
# left_gluteus_minimus                   0.91           0.93           NaN
# right_gluteus_minimus                  0.91           0.94           NaN
#
#                               NAKO T2 v1.2  AMOS MRI v1.1  AMOS MRI v1.2
# spleen                                0.92           0.95           0.94  \
# right_kidney                          0.97           0.95           0.95
# left_kidney                           0.96           0.95           0.94
# gallbladder                           0.83           0.74           0.73
# liver                                 0.96           0.96           0.96
# stomach                               0.88           0.87           0.87
# pancreas                              0.84           0.81           0.79
# right_adrenal_gland                   0.75           0.56           0.54
# left_adrenal_gland                    0.69           0.56           0.53
# left_lung                             0.96            NaN            NaN
# right_lung                            0.97            NaN            NaN
# heart                                 0.93            NaN            NaN
# aorta                                 0.95           0.90           0.89
# inferior_vena_cava                    0.91           0.83           0.83
# portal_vein_and_splenic_vein          0.81            NaN            NaN
# left_iliac_artery                      NaN            NaN            NaN
# right_iliac_artery                     NaN            NaN            NaN
# left_iliac_vena                        NaN            NaN            NaN
# right_iliac_vena                       NaN            NaN            NaN
# esophagus                             0.84           0.66           0.67
# small_bowel                           0.81            NaN            NaN
# duodenum                              0.66           0.58           0.59
# colon                                 0.86            NaN            NaN
# urinary_bladder                        NaN            NaN            NaN
# spine                                 0.94            NaN            NaN
# sacrum                                 NaN            NaN            NaN
# left_hip                               NaN            NaN            NaN
# right_hip                              NaN            NaN            NaN
# left_femur                             NaN            NaN            NaN
# right_femur                            NaN            NaN            NaN
# left_autochthonous_muscle             0.96            NaN            NaN
# right_autochthonous_muscle            0.96            NaN            NaN
# left_iliopsoas_muscle                 0.97            NaN            NaN
# right_iliopsoas_muscle                0.97            NaN            NaN
# left_gluteus_maximus                   NaN            NaN            NaN
# right_gluteus_maximus                  NaN            NaN            NaN
# left_gluteus_medius                    NaN            NaN            NaN
# right_gluteus_medius                   NaN            NaN            NaN
# left_gluteus_minimus                   NaN            NaN            NaN
# right_gluteus_minimus                  NaN            NaN            NaN
#
#                               AMOS CT v1.1  AMOS CT v1.2  TotSeg MRI v1.1
# spleen                                0.95          0.95             0.88  \
# right_kidney                          0.94          0.94             0.88
# left_kidney                           0.94          0.94             0.77
# gallbladder                           0.80          0.80             0.83
# liver                                 0.96          0.96             0.82
# stomach                               0.89          0.89             0.86
# pancreas                              0.79          0.79             0.45
# right_adrenal_gland                   0.70          0.69             0.56
# left_adrenal_gland                    0.69          0.69             0.66
# left_lung                              NaN           NaN             0.92
# right_lung                             NaN           NaN             0.81
# heart                                  NaN           NaN             0.81
# aorta                                 0.93          0.93             0.71
# inferior_vena_cava                    0.84          0.84             0.66
# portal_vein_and_splenic_vein           NaN           NaN             0.65
# left_iliac_artery                      NaN           NaN             0.71
# right_iliac_artery                     NaN           NaN             0.66
# left_iliac_vena                        NaN           NaN             0.74
# right_iliac_vena                       NaN           NaN             0.74
# esophagus                             0.80          0.81             0.61
# small_bowel                            NaN           NaN             0.78
# duodenum                              0.67          0.68             0.70
# colon                                  NaN           NaN             0.82
# urinary_bladder                        NaN           NaN             0.89
# spine                                  NaN           NaN             0.69
# sacrum                                 NaN           NaN             0.78
# left_hip                               NaN           NaN             0.65
# right_hip                              NaN           NaN             0.58
# left_femur                             NaN           NaN             0.80
# right_femur                            NaN           NaN             0.85
# left_autochthonous_muscle              NaN           NaN             0.70
# right_autochthonous_muscle             NaN           NaN             0.67
# left_iliopsoas_muscle                  NaN           NaN             0.53
# right_iliopsoas_muscle                 NaN           NaN             0.54
# left_gluteus_maximus                   NaN           NaN             0.83
# right_gluteus_maximus                  NaN           NaN             0.73
# left_gluteus_medius                    NaN           NaN             0.85
# right_gluteus_medius                   NaN           NaN             0.75
# left_gluteus_minimus                   NaN           NaN             0.85
# right_gluteus_minimus                  NaN           NaN             0.83
#
#                               TotSeg MRI v1.2
# spleen                                   0.89
# right_kidney                             0.89
# left_kidney                              0.77
# gallbladder                              0.84
# liver                                    0.82
# stomach                                  0.85
# pancreas                                 0.44
# right_adrenal_gland                      0.59
# left_adrenal_gland                       0.65
# left_lung                                0.92
# right_lung                               0.82
# heart                                    0.81
# aorta                                    0.69
# inferior_vena_cava                       0.65
# portal_vein_and_splenic_vein             0.62
# left_iliac_artery                        0.66
# right_iliac_artery                       0.63
# left_iliac_vena                          0.76
# right_iliac_vena                         0.74
# esophagus                                0.62
# small_bowel                              0.69
# duodenum                                 0.67
# colon                                    0.82
# urinary_bladder                          0.90
# spine                                    0.68
# sacrum                                   0.79
# left_hip                                 0.69
# right_hip                                0.57
# left_femur                               0.81
# right_femur                              0.86
# left_autochthonous_muscle                0.76
# right_autochthonous_muscle               0.69
# left_iliopsoas_muscle                    0.53
# right_iliopsoas_muscle                   0.55
# left_gluteus_maximus                     0.82
# right_gluteus_maximus                    0.70
# left_gluteus_medius                      0.88
# right_gluteus_medius                     0.75
# left_gluteus_minimus                     0.84
# right_gluteus_minimus                    0.83
